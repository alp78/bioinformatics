# %%
import pyensembl
from pyensembl import Genome
import pandas as pd
import csv
import pymysql
import operator
import time
import datetime
from termcolor import colored
import math

# %% [markdown]
# #### Import reference GTF to retrieve genes names by coordinates

# %%
# wget ftp://ftp.ensembl.org/pub/release-98/gtf/homo_sapiens/Homo_sapiens.GRCh38.98.gtf.gz
data = Genome(reference_name='GRCh38', annotation_name='98', gtf_path_or_url='REF/Homo_sapiens.GRCh38.98.gtf')

# %%
# data.index()

# %%
data.gene_names_at_locus(contig=1, position=630755, end=634922, strand='+')
# Out:
# ['MTATP6P1', 'MTATP8P1', 'MTCO1P12', 'MTCO2P12', 'MTCO3P12']

# %% [markdown]
# ### Processing transcript expression table from R

# %%
df_trans_expr = pd.read_csv('BALLGOWN_RES/bg_transcripts_expression.txt', sep='\t', skiprows=(0), header=(0))
df_trans_expr.head()
# Out:
#      t_id chr strand   start     end             t_name  num_exons  length  \
# 11     11   1      -   14409  192299          MSTRG.4.8          3    6817
# 47     47   1      -  185217  195411  ENST00000623083.4         10    1397
# 49     49   1      -  187891  187958  ENST00000612080.1          1      68
# 105   105   1      +  629062  629433  ENST00000416931.1          1     372
# 106   106   1      +  629084  630536          MSTRG.3.1          1    1453
#
#                gene_id  gene_name  ...   cov.BG12  FPKM.BG12   cov.BG13  \
# 11             MSTRG.4          .  ...  14.542374   1.442821  13.637791
# 47   ENSG00000279457.4     WASH9P  ...  19.456787   1.930404  26.013676
# 49   ENSG00000273874.1  MIR6859-2  ...  14.262753   1.415078  15.576286
# 105  ENSG00000225972.1   MTND1P23  ...   0.000000   0.000000   0.000000
# 106            MSTRG.3          .  ...   0.000000   0.000000   0.000000
#
#      FPKM.BG13   cov.BG14  FPKM.BG14   cov.BG15  FPKM.BG15   cov.BG16  \
# 11    1.766196  21.559107   2.694932  20.800241   2.111696  12.477324
# 47    3.368966  10.763598   1.345472  31.347738   3.182506   0.000000
# 49    2.017246  27.847542   3.480999  24.015854   2.438154  19.812614
# 105   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 106   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#      FPKM.BG16
# 11    1.154332
# 47    0.000000
# 49    1.832952
# 105   0.000000
# 106   0.000000
#
# [5 rows x 42 columns]

# %%
len(df_trans_expr)
# Out:
# 17306

# %% [markdown]
# ####  A) Retrieve all possible names from PYENSEMBL

# %%
# TRANSCRIPTS
# Query pyensembl to fill missing gene names (if exists)
# Store list of loci that have more than one gene name for querying UCSC
ambiguous = []
i = 0
j = 0
for index, row in df_trans_expr.iterrows():
    if row['gene_name'] == '.':
        name = data.gene_names_at_locus(strand=row['strand'], contig=row['chr'], position=row['start'], end=row['end'])
        if len(name) == 1:
            i+=1
            df_trans_expr.at[index, 'gene_name'] = name[0]
        elif len(name) > 1:
            k=0
            for token in name:
                if '.' in token:
                    k+=1
            if k == len(name) -1:
                for token in name:
                    if '.' not in token:
                        i+=1
                        df_trans_expr.at[index, 'gene_name'] = token
            else:
                j+=1
                ambiguous.append([row['gene_id'], name, row['strand'], row['chr'], row['start'], row['end']])
print(f'Filled {i} unique gene names. Appended {j} loci with multiple gene names to list.')
# Out:
# Filled 5201 unique gene names. Appended 1998 loci with multiple gene names to list.

# %%
df_trans_expr.head()
# Out:
#      t_id chr strand   start     end             t_name  num_exons  length  \
# 11     11   1      -   14409  192299          MSTRG.4.8          3    6817
# 47     47   1      -  185217  195411  ENST00000623083.4         10    1397
# 49     49   1      -  187891  187958  ENST00000612080.1          1      68
# 105   105   1      +  629062  629433  ENST00000416931.1          1     372
# 106   106   1      +  629084  630536          MSTRG.3.1          1    1453
#
#                gene_id  gene_name  ...   cov.BG12  FPKM.BG12   cov.BG13  \
# 11             MSTRG.4          .  ...  14.542374   1.442821  13.637791
# 47   ENSG00000279457.4     WASH9P  ...  19.456787   1.930404  26.013676
# 49   ENSG00000273874.1  MIR6859-2  ...  14.262753   1.415078  15.576286
# 105  ENSG00000225972.1   MTND1P23  ...   0.000000   0.000000   0.000000
# 106            MSTRG.3          .  ...   0.000000   0.000000   0.000000
#
#      FPKM.BG13   cov.BG14  FPKM.BG14   cov.BG15  FPKM.BG15   cov.BG16  \
# 11    1.766196  21.559107   2.694932  20.800241   2.111696  12.477324
# 47    3.368966  10.763598   1.345472  31.347738   3.182506   0.000000
# 49    2.017246  27.847542   3.480999  24.015854   2.438154  19.812614
# 105   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 106   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#      FPKM.BG16
# 11    1.154332
# 47    0.000000
# 49    1.832952
# 105   0.000000
# 106   0.000000
#
# [5 rows x 42 columns]

# %%
# Saving intermediary results
# df_trans_expr.to_csv('BALLGOWN_RES/bg_transcripts_expression.txt', sep='\t', index=False)

# %%
ambiguous[0]
# Out:
# ['MSTRG.4',
#  ['AL627309.1',
#   'AL627309.2',
#   'AL627309.3',
#   'AL627309.5',
#   'AL627309.6',
#   'AL627309.7',
#   'FAM138A',
#   'MIR6859-1',
#   'MIR6859-2',
#   'RNU6-1100P',
#   'WASH7P',
#   'WASH9P'],
#  '-',
#  '1',
#  14409,
#  192299]

# %% [markdown]
# #### option B) UCSC MYSQL

# %%
# UCSC mysql connection
conn = pymysql.connect(host='genome-mysql.cse.ucsc.edu',
                       db='hg38',
                       user='genome')

# %%
cur = conn.cursor()

# %%
query = 'SELECT DISTINCT knownGene.name, kgXref.geneSymbol \
FROM knownGene \
INNER JOIN kgXref ON knownGene.name = kgXref.kgID \
WHERE knownGene.chrom="chr{0}" \
AND knownGene.strand="{1}" \
AND (knownGene.cdsStart BETWEEN "{2}" AND "{3}") \
AND (knownGene.cdsEnd BETWEEN "{4}" AND "{5}") \
ORDER BY knownGene.name;'.format(row["chr"], 
                                 row["strand"], 
                                 row['start'], 
                                 row['end'], 
                                 row['start'], 
                                 row['end'])
query
# Out:
# 'SELECT DISTINCT knownGene.name, kgXref.geneSymbol FROM knownGene INNER JOIN kgXref ON knownGene.name = kgXref.kgID WHERE knownGene.chrom="chrY" AND knownGene.strand="+" AND (knownGene.cdsStart BETWEEN "21257840" AND "21291598") AND (knownGene.cdsEnd BETWEEN "21257840" AND "21291598") ORDER BY knownGene.name;'

# %%
# TRANSCRIPTS
# Query UCSC mysql server to fill missing gene names 
# search which gene(s) have their CDS starting and ending within the query range
# select the gene name that has the most transcripts assigned to it within the range
# Store list of loci that were not mapped to any name
unknown_list = []
i = 0
j = 0
for index, row in df_trans_expr.iterrows():
    if row['gene_name'] == '.':
        query = 'SELECT DISTINCT knownGene.name, kgXref.geneSymbol \
        FROM knownGene \
        INNER JOIN kgXref ON knownGene.name = kgXref.kgID \
        WHERE knownGene.chrom="chr{0}" \
        AND knownGene.strand="{1}" \
        AND (knownGene.cdsStart BETWEEN "{2}" AND "{3}") \
        AND (knownGene.cdsEnd BETWEEN "{4}" AND "{5}") \
        ORDER BY knownGene.name;'.format(row["chr"], 
                                         row["strand"], 
                                         row['start'], 
                                         row['end'], 
                                         row['start'], 
                                         row['end'])
        cur.execute(query)
        genes_list = []
        for record in cur:
            if record[1] not in genes_list:
                genes_list.append(record[1])
        if len(genes_list) > 0:
            gname = ''
            i+=1
            if len(set(genes_list)) > 1:
                print(colored('MULTI', 'yellow'), end=':  ')
            else:
                print(colored('UNIQUE', 'green'), end=':  ')
            for name in list(set(genes_list)):
                gname = gname + name + ':'
            gname = gname[:-1]
            #print(row["chr"] + ' ' + row["strand"] + ' ' + str(row['start']) + ' ' + str(row['end']) + ' --> ' + gname)
            df_trans_expr.at[index, 'gene_name'] = gname
        else:
            j+=1
            gname = row["chr"] + ':' + row["strand"] + ':' + str(row['start']) + ':' + str(row['end'])
            df_trans_expr.at[index, 'gene_name'] = gname
            #print(colored('UNKNOWN', 'red') + ':  ' + row["chr"] + ':' + row["strand"] + ':' + str(row['start']) + ':' + str(row['end']))
            unknown_list.append([row['gene_id'], row['strand'], row['chr'], row['start'], row['end']])
print(f'Filled {i} gene names. {j} remain unknown, named by coordinates')
# Out:
# UNKNOWN:  1:-:736352:739978
# UNKNOWN:  1:-:83444156:83480511
# UNKNOWN:  1:-:83444156:83480511
# UNKNOWN:  1:-:120844145:120844351
# UNKNOWN:  1:+:148529266:148529605
# UNKNOWN:  1:-:148661558:148712561
# UNKNOWN:  1:+:149636775:149640548
# UNKNOWN:  1:+:154999283:154999543
# UNKNOWN:  1:+:204506512:204506849
# UNKNOWN:  1:+:205957922:205958388
# UNKNOWN:  1:+:225999557:226007436
# UNKNOWN:  1:-:234610322:234610871
# UNKNOWN:  1:-:239623842:239624169
# UNKNOWN:  10:+:14185474:14186811
# UNKNOWN:  10:+:16891899:16892262
# UNKNOWN:  10:-:61903338:61903844
# UNKNOWN:  10:-:68632600:68632836
# UNKNOWN:  10:+:131751695:131756262
# UNKNOWN:  11:-:10509215:10509928
# UNKNOWN:  11:+:55898320:55898546
# UNKNOWN:  11:-:59550259:59551043
# UNKNOWN:  11:-:60072542:60072761
# UNKNOWN:  11:-:66183136:66183764
# UNKNOWN:  11:-:68459959:68460220
# UNKNOWN:  11:+:85483965:85484177
# UNKNOWN:  11:-:96346435:96346769
# UNKNOWN:  12:-:7723328:7728578
# UNKNOWN:  12:+:29833746:29853986
# UNKNOWN:  12:-:47218122:47218385
# UNKNOWN:  12:-:66003355:66003737
# UNKNOWN:  12:-:80408908:80485797
# UNKNOWN:  12:-:80454419:80485797
# UNKNOWN:  12:-:80464096:80483390
# UNKNOWN:  KI270846.1:-:92121:116157
# UNKNOWN:  KI270846.1:-:92130:217406
# UNKNOWN:  KI270846.1:-:92342:114600
# UNKNOWN:  KI270846.1:-:92342:114600
# UNKNOWN:  KI270846.1:-:92342:116157
# UNKNOWN:  KI270846.1:-:92342:117064
# UNKNOWN:  KI270846.1:-:92365:242795
# UNKNOWN:  KI270846.1:-:96682:97501
# UNKNOWN:  KI270846.1:+:97517:269551
# UNKNOWN:  KI270846.1:-:107339:131944
# UNKNOWN:  KI270846.1:-:110870:241410
# UNKNOWN:  KI270846.1:-:110879:116157
# UNKNOWN:  KI270846.1:-:111004:243619
# UNKNOWN:  KI270846.1:-:112272:116094
# UNKNOWN:  KI270846.1:+:115396:145572
# UNKNOWN:  KI270846.1:-:169155:178562
# UNKNOWN:  KI270846.1:-:174857:178562
# UNKNOWN:  KI270846.1:-:174873:178562
# UNKNOWN:  KI270846.1:-:174884:178985
# UNKNOWN:  KI270846.1:-:174884:179240
# UNKNOWN:  KI270846.1:-:175554:178562
# UNKNOWN:  KI270846.1:-:175562:178985
# UNKNOWN:  KI270846.1:-:209086:212507
# UNKNOWN:  KI270846.1:-:209097:242795
# UNKNOWN:  KI270846.1:-:209097:243619
# UNKNOWN:  KI270846.1:-:209097:244236
# UNKNOWN:  KI270846.1:-:209104:242795
# UNKNOWN:  KI270846.1:-:231894:234891
# UNKNOWN:  KI270846.1:-:236788:244236
# UNKNOWN:  KI270846.1:-:236809:244236
# UNKNOWN:  KI270846.1:-:236842:239993
# UNKNOWN:  KI270846.1:-:236871:244236
# UNKNOWN:  KI270846.1:-:313054:333175
# UNKNOWN:  KI270846.1:-:313144:331582
# UNKNOWN:  KI270846.1:-:313144:331983
# UNKNOWN:  KI270846.1:-:313144:332355
# UNKNOWN:  KI270846.1:-:313144:374683
# UNKNOWN:  KI270846.1:-:313146:324905
# UNKNOWN:  KI270846.1:-:319411:333175
# UNKNOWN:  KI270846.1:-:319459:324905
# UNKNOWN:  KI270846.1:-:319470:331582
# UNKNOWN:  KI270846.1:-:319470:331582
# UNKNOWN:  KI270846.1:-:319471:333175
# UNKNOWN:  KI270846.1:-:319473:332355
# UNKNOWN:  KI270846.1:-:319473:332355
# UNKNOWN:  KI270846.1:-:319473:332355
# UNKNOWN:  KI270846.1:-:319473:333175
# UNKNOWN:  KI270846.1:-:319473:333221
# UNKNOWN:  KI270846.1:-:319474:331582
# UNKNOWN:  KI270846.1:-:319476:333221
# UNKNOWN:  KI270846.1:-:319476:333221
# UNKNOWN:  KI270846.1:-:319476:333221
# UNKNOWN:  KI270846.1:-:319476:333221
# UNKNOWN:  KI270846.1:-:319484:333175
# UNKNOWN:  KI270846.1:-:321991:331582
# UNKNOWN:  KI270846.1:-:321993:331582
# UNKNOWN:  KI270846.1:-:321997:324905
# UNKNOWN:  KI270846.1:-:321997:332355
# UNKNOWN:  KI270846.1:-:326350:332355
# UNKNOWN:  KI270846.1:-:349305:360896
# UNKNOWN:  KI270846.1:+:351825:388305
# UNKNOWN:  KI270846.1:+:358274:866999
# UNKNOWN:  KI270846.1:+:363410:366647
# UNKNOWN:  KI270846.1:+:366875:411397
# UNKNOWN:  KI270846.1:-:372453:865643
# UNKNOWN:  KI270846.1:-:407457:408872
# UNKNOWN:  KI270846.1:-:454348:454892
# UNKNOWN:  KI270846.1:-:454348:590345
# UNKNOWN:  KI270846.1:-:505674:506367
# UNKNOWN:  KI270846.1:-:523385:585048
# UNKNOWN:  KI270846.1:-:530072:1030007
# UNKNOWN:  KI270846.1:-:556054:1030007
# UNKNOWN:  KI270846.1:-:575739:576332
# UNKNOWN:  KI270846.1:-:702829:703439
# UNKNOWN:  KI270846.1:-:702830:1030007
# UNKNOWN:  KI270846.1:-:802848:803643
# UNKNOWN:  KI270846.1:-:802848:827339
# UNKNOWN:  KI270846.1:-:826781:851986
# UNKNOWN:  KI270846.1:-:913386:1131189
# UNKNOWN:  KI270846.1:-:913386:1131339
# UNKNOWN:  KI270846.1:-:1048613:1049355
# UNKNOWN:  KI270846.1:-:1114033:1115752
# UNKNOWN:  KI270846.1:-:1114033:1116325
# UNKNOWN:  KI270846.1:-:1118926:1131339
# UNKNOWN:  KI270846.1:-:1206360:1206903
# UNKNOWN:  KI270846.1:-:1206361:1253848
# UNKNOWN:  KI270846.1:-:1253356:1253848
# UNKNOWN:  KI270847.1:-:1165494:1195752
# UNKNOWN:  KI270847.1:-:1165530:1195752
# UNKNOWN:  KI270847.1:-:1165552:1194298
# UNKNOWN:  KI270849.1:+:34786:46255
# UNKNOWN:  KI270849.1:+:34850:49167
# UNKNOWN:  KI270849.1:+:34857:43644
# UNKNOWN:  KI270849.1:+:34859:43644
# UNKNOWN:  KI270849.1:+:34872:46255
# UNKNOWN:  KI270849.1:+:34875:43644
# UNKNOWN:  KI270850.1:-:161303:162019
# UNKNOWN:  KI270850.1:-:325829:329545
# UNKNOWN:  KI270850.1:-:325833:329545
# UNKNOWN:  KI270853.1:-:671779:694564
# UNKNOWN:  KI270853.1:-:717654:719281
# UNKNOWN:  KI270857.1:+:2757626:2765281
# UNKNOWN:  KI270857.1:+:2759941:2765281
# UNKNOWN:  KI270862.1:-:286556:342249
# UNKNOWN:  KI270867.1:-:102381:132749
# UNKNOWN:  KI270867.1:-:141002:148537
# UNKNOWN:  KI270875.1:+:67465:68103
# UNKNOWN:  KI270876.1:-:159252:159695
# UNKNOWN:  KI270897.1:+:80598:141268
# UNKNOWN:  KI270897.1:+:114836:141268
# UNKNOWN:  KI270897.1:+:116043:141268
# UNKNOWN:  KI270897.1:-:733525:748499
# UNKNOWN:  KI270897.1:+:985695:988839
# UNKNOWN:  KI270905.1:-:301804:303100
# UNKNOWN:  KI270905.1:+:562889:563298
# UNKNOWN:  KI270905.1:-:1541168:1545760
# UNKNOWN:  KI270905.1:+:2015457:2015943
# UNKNOWN:  KI270908.1:-:195278:223411
# UNKNOWN:  KI270908.1:-:202054:223411
# UNKNOWN:  KI270908.1:-:203607:221655
# UNKNOWN:  KI270908.1:-:204663:221655
# UNKNOWN:  KI270908.1:+:310706:311119
# UNKNOWN:  KI270908.1:+:1143853:1157220
# UNKNOWN:  Y:+:21228146:21257794
# UNKNOWN:  Y:+:21228146:21276468
# UNKNOWN:  Y:+:21228146:21291598
# UNKNOWN:  Y:+:21228146:21291598
# UNKNOWN:  Y:+:21228146:21306771
# UNKNOWN:  Y:+:21228146:21308122
# UNKNOWN:  Y:+:21228148:21257794
# UNKNOWN:  Y:+:21228148:21276468
# UNKNOWN:  Y:+:21257840:21291598
# Filled 0 gene names. 791 remain unknown, named by coordinates

# %%
cur.close()

# %%
unknown_list[500:505]
# Out:
# [['MSTRG.14127', '+', 'KI270733.1', 122287, 179772],
#  ['MSTRG.14127', '+', 'KI270733.1', 122591, 125718],
#  ['MSTRG.14127', '+', 'KI270733.1', 122594, 128594],
#  ['MSTRG.14127', '+', 'KI270733.1', 124065, 128594],
#  ['MSTRG.14127', '+', 'KI270733.1', 124070, 179772]]

# %%
df_trans_expr.head()
# Out:
#      t_id chr strand   start     end             t_name  num_exons  length  \
# 11     11   1      -   14409  192299          MSTRG.4.8          3    6817
# 47     47   1      -  185217  195411  ENST00000623083.4         10    1397
# 49     49   1      -  187891  187958  ENST00000612080.1          1      68
# 105   105   1      +  629062  629433  ENST00000416931.1          1     372
# 106   106   1      +  629084  630536          MSTRG.3.1          1    1453
#
#                gene_id                                          gene_name  \
# 11             MSTRG.4  AL627309.3:MIR6859-1:AL627309.2:AL627309.6:MIR...
# 47   ENSG00000279457.4                                             WASH9P
# 49   ENSG00000273874.1                                          MIR6859-2
# 105  ENSG00000225972.1                                           MTND1P23
# 106            MSTRG.3                                           MTND2P28
#
#      ...   cov.BG12  FPKM.BG12   cov.BG13  FPKM.BG13   cov.BG14  FPKM.BG14  \
# 11   ...  14.542374   1.442821  13.637791   1.766196  21.559107   2.694932
# 47   ...  19.456787   1.930404  26.013676   3.368966  10.763598   1.345472
# 49   ...  14.262753   1.415078  15.576286   2.017246  27.847542   3.480999
# 105  ...   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 106  ...   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#       cov.BG15  FPKM.BG15   cov.BG16  FPKM.BG16
# 11   20.800241   2.111696  12.477324   1.154332
# 47   31.347738   3.182506   0.000000   0.000000
# 49   24.015854   2.438154  19.812614   1.832952
# 105   0.000000   0.000000   0.000000   0.000000
# 106   0.000000   0.000000   0.000000   0.000000
#
# [5 rows x 42 columns]

# %%
len(df_trans_expr)
# Out:
# 17306

# %%
# Export for further processing in R
df_trans_expr.to_csv('BALLGOWN_RES/bg_transcripts_expression_OK.txt', sep='\t', index=False)

# %%
# create dictionary mapping gene_ids to their names from  df_gene_expr for later mapping
i=0
names_dict = {}
for index, row in df_trans_expr.iterrows():
    if row['gene_name'] != '.' and row['gene_id'] not in names_dict:
        i+=1
        names_dict[row['gene_id']] = row['gene_name']
        
print(f'Added {i} gene names to dictionary')
# Out:
# Added 8847 gene names to dictionary

# %%
# ALTERNATIVE: add coordinates to dic to fill in datasets
i=0
names_coord_dict = {}
for index, row in df_trans_expr.iterrows():
   # if row['gene_name'] != '.' and row['gene_id'] not in names_coord_dict:
    i+=1
    names_coord_dict[row['gene_id']] = [row['gene_name'], row['chr'], row['strand'], row['start'], row['end']]
print(f'Added {i} gene names to dictionary')
# Out:
# Added 17306 gene names to dictionary

# %%
i=0
for k,v in names_coord_dict.items():
    print(k,v)
    i+=1
    if i==3:
        break
# Out:
# MSTRG.4 ['AL627309.3:MIR6859-1:AL627309.2:AL627309.6:MIR6859-2:WASH9P:AL627309.1:AL627309.7:AL627309.5:RNU6-1100P:FAM138A', '1', '-', 14409, 192299]
# ENSG00000279457.4 ['WASH9P', '1', '-', 185217, 195411]
# ENSG00000273874.1 ['MIR6859-2', '1', '-', 187891, 187958]

# %% [markdown]
# ### Stringtie - Limma

# %%
# import gene_ids list from LIMMA step
df_gene_ids = pd.read_csv('LIMMA_RES/limma_stringtie_geneids.txt', sep='\t', skiprows=(0), header=(0))
df_gene_ids.head()
# Out:
#            ENSEMBL     SYMBOL
# 0  ENSG00000280143        NaN
# 1  ENSG00000146083      RNF44
# 2  ENSG00000269416  LINC01224
# 3  ENSG00000231981        NaN
# 4  ENSG00000134108      ARL8B

# %%
# how to check if NaN --> NaN != NaN is True
df_gene_ids['SYMBOL'][0] != df_gene_ids['SYMBOL'][0]
# Out:
# True

# %%
# Pyensembl function retrieves gene name from ID
data.gene_name_of_gene_id('ENSG00000260500')
# Out:
# 'AC010336.2'

# %%
# loop over the dataframe and add missing ENSEMBL gene names
i = 0
j = 0
k = 0
for idx, row in df_gene_ids.iterrows():
    if ('ENS' in row['ENSEMBL']) and (row['SYMBOL'] != row['SYMBOL']):
        gname = ''
        gname = data.gene_name_of_gene_id(row['ENSEMBL'])
        if gname != '':
            i+=1
        else:
            j+=1
        df_gene_ids.at[idx, 'SYMBOL'] = gname
    elif 'MSTRG' in row['ENSEMBL']:
        k+=1
print(f'Filled {i} ENSEMBL symbols, still {j} ENSEMBL and {k} MSTRG missing.')
# Out:
# Filled 11228 ENSEMBL symbols, still 0 ENSEMBL and 0 MSTRG missing.

# %%
df_gene_ids.to_csv('LIMMA_RES/limma_stringtie_geneids_OK.txt', sep='\t', index=False)

# %% [markdown]
# #### Filling missing gene names in RESULTS_GENES from R using names_dic

# %%
df_res_genes = pd.read_csv('BALLGOWN_RES/bg_results_genes.txt', sep='\t', skiprows=(0), header=(0))

# %%
df_res_genes.head()
# Out:
#   geneNames feature                  id        fc      pval      qval
# 1      DPM1    gene  ENSG00000000419.12  0.952968  0.861807  0.996319
# 2       FGR    gene  ENSG00000000938.13  0.751023  0.305573  0.986386
# 3      GCLC    gene  ENSG00000001084.13  0.986426  0.963085  0.998285
# 4      NFYA    gene  ENSG00000001167.14  1.268874  0.285631  0.986386
# 5     LAS1L    gene  ENSG00000001497.16  1.059891  0.790692  0.996319

# %%
len(df_res_genes)
# Out:
# 8847

# %%
# count how many missing gene names
count = 0
for index, row in df_res_genes.iterrows():
    if row['geneNames'] == '.':
        count += 1
print(f'{count} missing gene names')
# Out:
# 3871 missing gene names

# %%
# filling missing gene names when they exist in names_dict
i=0
j=0
for geneIndex, geneRow in df_res_genes.iterrows():
    if geneRow['geneNames'] == '.' and geneRow['id'] in names_dict:
        i+=1
        df_res_genes.at[geneIndex, 'geneNames'] = names_dict[geneRow['id']]
    elif geneRow['geneNames'] == '.' and geneRow['id'] not in names_dict:
        j+=1
print(f'Filled {i} gene names, still {j} missing')
# Out:
# Filled 3871 gene names, still 0 missing

# %%
df_res_genes
# Out:
#      geneNames feature                  id        fc      pval      qval
# 1         DPM1    gene  ENSG00000000419.12  0.952968  0.861807  0.996319
# 2          FGR    gene  ENSG00000000938.13  0.751023  0.305573  0.986386
# 3         GCLC    gene  ENSG00000001084.13  0.986426  0.963085  0.998285
# 4         NFYA    gene  ENSG00000001167.14  1.268874  0.285631  0.986386
# 5        LAS1L    gene  ENSG00000001497.16  1.059891  0.790692  0.996319
# ...        ...     ...                 ...       ...       ...       ...
# 8843         .    gene          MSTRG.9972  0.731863  0.219093  0.986386
# 8844         .    gene          MSTRG.9979  1.418171  0.463434  0.986386
# 8845         .    gene          MSTRG.9988  0.803171  0.409197  0.986386
# 8846         .    gene          MSTRG.9994  1.265494  0.332189  0.986386
# 8847         .    gene          MSTRG.9997  0.932601  0.763101  0.996319
#
# [8847 rows x 6 columns]

# %%
# ALTERNATIVE: add coordinates columns
# structure of list: [row['gene_name'], row['chr'], row['strand'], row['start'], row['end']]
i=0
j=0
for geneIndex, geneRow in df_res_genes.iterrows():
    if geneRow['id'] in names_coord_dict:
        i+=1
        df_res_genes.at[geneIndex, 'geneNames'] = names_coord_dict[geneRow['id']][0]
        df_res_genes.at[geneIndex, 'chr'] = names_coord_dict[geneRow['id']][1]
        df_res_genes.at[geneIndex, 'strand'] = names_coord_dict[geneRow['id']][2]
        df_res_genes.at[geneIndex, 'start'] = str(int(names_coord_dict[geneRow['id']][3]))
        df_res_genes.at[geneIndex, 'end'] = str(int(names_coord_dict[geneRow['id']][4]))
    elif geneRow['geneNames'] == '.' and geneRow['id'] not in names_coord_dict:
        j+=1
print(f'Filled {i} gene names, still {j} missing')
# Out:
# Filled 8847 gene names, still 0 missing

# %%
len(df_res_genes)
# Out:
# 8847

# %%
# remove unrecognized genes from dataframe
i = 0
for idx, row in df_res_genes.iterrows():
    if row['geneNames'] == '.':
        i+=1
        df_res_genes.drop(index = idx, inplace=True)
print(f'Removed {i} records missing gene names')
# Out:
# Removed 2068 records missing gene names

# %%
df_res_genes
# Out:
#                               geneNames feature                  id        fc  \
# 1                                  DPM1    gene  ENSG00000000419.12  0.952968
# 2                                   FGR    gene  ENSG00000000938.13  0.751023
# 3                                  GCLC    gene  ENSG00000001084.13  0.986426
# 4                                  NFYA    gene  ENSG00000001167.14  1.268874
# 5                                 LAS1L    gene  ENSG00000001497.16  1.059891
# ...                                 ...     ...                 ...       ...
# 8843                              RUBCN    gene          MSTRG.9972  0.731863
# 8844                             RPL35A    gene          MSTRG.9979  1.418171
# 8845  MIR571:ZNF519P4:ZNF141:AC092574.2    gene          MSTRG.9988  0.803171
# 8846                              PCGF3    gene          MSTRG.9994  1.265494
# 8847                                GAK    gene          MSTRG.9997  0.932601
#
#           pval      qval chr strand      start        end
# 1     0.861807  0.996319  20      -   50934867   50958550
# 2     0.305573  0.986386   1      -   27612669   27626569
# 3     0.963085  0.998285   6      -   53498756   53544645
# 4     0.285631  0.986386   6      +   41072983   41097950
# 5     0.790692  0.996319   X      -   65512582   65534754
# ...        ...       ...  ..    ...        ...        ...
# 8843  0.219093  0.986386   3      -  197688282  197736907
# 8844  0.463434  0.986386   3      +  197950183  197955899
# 8845  0.409197  0.986386   4      +     337814     393561
# 8846  0.332189  0.986386   4      +     705781     770096
# 8847  0.763101  0.996319   4      -     849192     932356
#
# [8847 rows x 10 columns]

# %%
len(df_res_genes)
# Out:
# 8847

# %%
# write final table
df_res_genes.to_csv('BALLGOWN_RES/bg_results_genes_OK.txt', sep='\t', index=False)

# %% [markdown]
# #### Filling missing gene names in GENE_EXPRESSION from R using previous names_dict

# %%
df_gen_expr = pd.read_csv('BALLGOWN_RES/bg_gene_expression.txt', sep='\t', skiprows=(0), header=(0))

# %%
df_gen_expr.head()
# Out:
#    FPKM.BG01  FPKM.BG02  FPKM.BG03  FPKM.BG04  FPKM.BG05  FPKM.BG06  \
# 1   3.071421   2.308293   0.167408   0.558109   2.590572   3.826903
# 2  14.779531  24.619555   6.184224  25.636282  34.901442  20.169939
# 3   1.140217   1.232682   1.711690   1.948833   0.962728   0.683622
# 4   1.679026   1.580273   3.008221   5.118732   0.459134   1.543150
# 5   0.932872   1.918391   1.733324   3.588534   0.734940   2.296339
#
#    FPKM.BG07  FPKM.BG08  FPKM.BG09  FPKM.BG10  FPKM.BG11  FPKM.BG12  \
# 1   2.359116   3.349323   1.032477   0.379715   5.431262   1.725221
# 2  23.045040  18.480485  39.090947  17.870318   6.338989   3.991157
# 3   1.750154   4.797488   0.593104   5.229822   0.020015   0.786516
# 4   2.100641   1.451065   1.821235   1.569821   1.764375   2.592938
# 5   3.210236   2.252500   4.025122   3.611774   3.895302   0.717748
#
#    FPKM.BG13  FPKM.BG14  FPKM.BG15  FPKM.BG16  controlMeans   cthMeans  \
# 1   4.404366   5.050120   0.921382   3.273753      2.278893   2.777287
# 2   5.079023  16.229340  15.831924  10.421323     20.977062  14.356628
# 3   0.000000   2.847026   3.279366   2.021713      1.778427   1.847195
# 4   3.985546   4.741767   4.485174   1.161270      2.117530   2.765266
# 5   0.678119   1.487848   2.199041   0.956867      2.083392   2.196478
#
#   geneNames             geneIDs
# 1      DPM1  ENSG00000000419.12
# 2       FGR  ENSG00000000938.13
# 3      GCLC  ENSG00000001084.13
# 4      NFYA  ENSG00000001167.14
# 5     LAS1L  ENSG00000001497.16

# %%
i=0
j=0
for geneIndex, geneRow in df_gen_expr.iterrows():
    if geneRow['geneNames'] == '.' and geneRow['geneIDs'] in names_dict:
        i+=1
        df_gen_expr.at[geneIndex, 'geneNames'] = names_dict[geneRow['geneIDs']]
    elif geneRow['geneNames'] == '.' and geneRow['geneIDs'] not in names_dict:
        j+=1
print(f'Filled {i} gene names, still {j} missing')
# Out:
# Filled 3871 gene names, still 0 missing

# %%
df_gen_expr.head()
# Out:
#    FPKM.BG01  FPKM.BG02  FPKM.BG03  FPKM.BG04  FPKM.BG05  FPKM.BG06  \
# 1   3.071421   2.308293   0.167408   0.558109   2.590572   3.826903
# 2  14.779531  24.619555   6.184224  25.636282  34.901442  20.169939
# 3   1.140217   1.232682   1.711690   1.948833   0.962728   0.683622
# 4   1.679026   1.580273   3.008221   5.118732   0.459134   1.543150
# 5   0.932872   1.918391   1.733324   3.588534   0.734940   2.296339
#
#    FPKM.BG07  FPKM.BG08  FPKM.BG09  FPKM.BG10  FPKM.BG11  FPKM.BG12  \
# 1   2.359116   3.349323   1.032477   0.379715   5.431262   1.725221
# 2  23.045040  18.480485  39.090947  17.870318   6.338989   3.991157
# 3   1.750154   4.797488   0.593104   5.229822   0.020015   0.786516
# 4   2.100641   1.451065   1.821235   1.569821   1.764375   2.592938
# 5   3.210236   2.252500   4.025122   3.611774   3.895302   0.717748
#
#    FPKM.BG13  FPKM.BG14  FPKM.BG15  FPKM.BG16  controlMeans   cthMeans  \
# 1   4.404366   5.050120   0.921382   3.273753      2.278893   2.777287
# 2   5.079023  16.229340  15.831924  10.421323     20.977062  14.356628
# 3   0.000000   2.847026   3.279366   2.021713      1.778427   1.847195
# 4   3.985546   4.741767   4.485174   1.161270      2.117530   2.765266
# 5   0.678119   1.487848   2.199041   0.956867      2.083392   2.196478
#
#   geneNames             geneIDs
# 1      DPM1  ENSG00000000419.12
# 2       FGR  ENSG00000000938.13
# 3      GCLC  ENSG00000001084.13
# 4      NFYA  ENSG00000001167.14
# 5     LAS1L  ENSG00000001497.16

# %%
# remove unrecognized genes from dataframe
i = 0
for idx, row in df_gen_expr.iterrows():
    if row['geneNames'] == '.':
        i+=1
        df_gen_expr.drop(index = idx, inplace=True)
print(f'Removed {i} records missing gene names')
# Out:
# Removed 2068 records missing gene names

# %%
len(df_gen_expr)
# Out:
# 8847

# %%
cols = list(df_gen_expr.columns)
cols
# Out:
# ['FPKM.BG01',
#  'FPKM.BG02',
#  'FPKM.BG03',
#  'FPKM.BG04',
#  'FPKM.BG05',
#  'FPKM.BG06',
#  'FPKM.BG07',
#  'FPKM.BG08',
#  'FPKM.BG09',
#  'FPKM.BG10',
#  'FPKM.BG11',
#  'FPKM.BG12',
#  'FPKM.BG13',
#  'FPKM.BG14',
#  'FPKM.BG15',
#  'FPKM.BG16',
#  'controlMeans',
#  'cthMeans',
#  'geneNames',
#  'geneIDs']

# %%
# rearrange columns order
df_gen_expr = df_gen_expr[[cols[-1], cols[-2], cols[0], cols[1], cols[2], cols[3], 
                           cols[4], cols[5], cols[6], cols[7], cols[8], cols[9], 
                           cols[10], cols[11], cols[12], cols[13], cols[14], cols[15], 
                           cols[16], cols[17]]]
df_gen_expr.head()
# Out:
#               geneIDs geneNames  FPKM.BG01  FPKM.BG02  FPKM.BG03  FPKM.BG04  \
# 1  ENSG00000000419.12      DPM1   3.071421   2.308293   0.167408   0.558109
# 2  ENSG00000000938.13       FGR  14.779531  24.619555   6.184224  25.636282
# 3  ENSG00000001084.13      GCLC   1.140217   1.232682   1.711690   1.948833
# 4  ENSG00000001167.14      NFYA   1.679026   1.580273   3.008221   5.118732
# 5  ENSG00000001497.16     LAS1L   0.932872   1.918391   1.733324   3.588534
#
#    FPKM.BG05  FPKM.BG06  FPKM.BG07  FPKM.BG08  FPKM.BG09  FPKM.BG10  \
# 1   2.590572   3.826903   2.359116   3.349323   1.032477   0.379715
# 2  34.901442  20.169939  23.045040  18.480485  39.090947  17.870318
# 3   0.962728   0.683622   1.750154   4.797488   0.593104   5.229822
# 4   0.459134   1.543150   2.100641   1.451065   1.821235   1.569821
# 5   0.734940   2.296339   3.210236   2.252500   4.025122   3.611774
#
#    FPKM.BG11  FPKM.BG12  FPKM.BG13  FPKM.BG14  FPKM.BG15  FPKM.BG16  \
# 1   5.431262   1.725221   4.404366   5.050120   0.921382   3.273753
# 2   6.338989   3.991157   5.079023  16.229340  15.831924  10.421323
# 3   0.020015   0.786516   0.000000   2.847026   3.279366   2.021713
# 4   1.764375   2.592938   3.985546   4.741767   4.485174   1.161270
# 5   3.895302   0.717748   0.678119   1.487848   2.199041   0.956867
#
#    controlMeans   cthMeans
# 1      2.278893   2.777287
# 2     20.977062  14.356628
# 3      1.778427   1.847195
# 4      2.117530   2.765266
# 5      2.083392   2.196478

# %%
# write final table
df_gen_expr.to_csv('BALLGOWN_RES/bg_gene_expression_OK.txt', sep='\t', index=False)

# %% [markdown]
# #### Filling missing gene names in RESULTS_TRANSCRIPTS from R using names_dict dictionary

# %%
df_res_trans = pd.read_csv('BALLGOWN_RES/bg_results_transcripts.txt', sep='\t', skiprows=(0), header=(0))
df_res_trans.head()
# Out:
#      geneNames            geneIDs     feature   id        fc      pval  \
# 11           .            MSTRG.4  transcript   11  0.977377  0.916292
# 47      WASH9P  ENSG00000279457.4  transcript   47  1.039621  0.905665
# 49   MIR6859-2  ENSG00000273874.1  transcript   49  0.880317  0.363163
# 105   MTND1P23  ENSG00000225972.1  transcript  105  0.709631  0.271116
# 106          .            MSTRG.3  transcript  106  0.804507  0.767515
#
#          qval      mean
# 11   0.993393  1.880625
# 47   0.992615  1.987511
# 49   0.959959  2.670518
# 105  0.959959  0.506457
# 106  0.978429  6.057494

# %%
# count how many missing gene names
count = 0
for index, row in df_res_trans.iterrows():
    if row['geneNames'] == '.':
        count += 1
print(f'{count} missing gene names')
# Out:
# 7995 missing gene names

# %%
# filling missing gene names when they exist in names_dict
i=0
j=0
for geneIndex, geneRow in df_res_trans.iterrows():
    if geneRow['geneNames'] == '.' and geneRow['geneIDs'] in names_dict:
        i+=1
        df_res_trans.at[geneIndex, 'geneNames'] = names_dict[geneRow['geneIDs']]
    elif geneRow['geneNames'] == '.' and geneRow['geneIDs'] not in names_dict:
        j+=1
print(f'Filled {i} gene names, still {j} missing')
# Out:
# Filled 7995 gene names, still 0 missing

# %%
# remove unrecognized genes from dataframe
i = 0
for idx, row in df_res_trans.iterrows():
    if row['geneNames'] == '.':
        i+=1
        df_res_trans.drop(index = idx, inplace=True)
print(f'Removed {i} records missing gene names')
# Out:
# Removed 4240 records missing gene names

# %%
len(df_res_trans)
# Out:
# 17306

# %%
# write final table
df_res_trans.to_csv('BALLGOWN_RES/bg_results_transcripts_OK.txt', sep='\t', index=False)
